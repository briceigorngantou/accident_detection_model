# %%
# !pip install opencv-python
# Out:
# Requirement already satisfied: opencv-python in c:\users\brice\anaconda3\lib\site-packages (4.9.0.80)
# Requirement already satisfied: numpy>=1.21.2 in c:\users\brice\anaconda3\lib\site-packages (from opencv-python) (1.26.4)

# %%
import os
import cv2
import numpy as np
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestClassifier

# %%
print(cv2.__version__)
# Out:
# 4.9.0

# %%
input_size=200

# %%
# Chargement des images depuis un dossier
image_folder = "./dataset/images/"
images = os.listdir(image_folder)
images = [os.path.join(image_folder, img) for img in images]
images[30]
# Out:
# './dataset/images/acc1-6-_jpg.rf.0acbfc206f6e8d9021f00903414e7909.jpg'

# %%
# Chargement des labels depuis un dossier
labels_folder = "./dataset/labels/"
labels = os.listdir(labels_folder)
labels = [os.path.join(labels_folder, label) for label in labels]
labels[30]
# Out:
# './dataset/labels/acc1-6-_jpg.rf.0acbfc206f6e8d9021f00903414e7909.txt'

# %%
# Script to parse bounding box coordinates from text files

# Function to parse bounding box coordinates from a text file
def parse_bounding_boxes(text_file_paths):
    bounding_boxes = {}
    for text_file in text_file_paths:
        # Derive the corresponding image file path
        image_file = text_file.replace('.txt', '.jpg')
        image_file1 = image_file.replace('labels', 'images')
        with open(text_file, 'r') as file:
            data = file.read()
            # Each line in the file is a separate bounding box
            boxes = data.strip().split('\n')
            # Parse each box coordinate
            box_coords = [tuple(map(float, box.split())) for box in boxes]
            bounding_boxes[image_file1] = box_coords
    return bounding_boxes

# Calling the function with our example text files
bounding_boxes = parse_bounding_boxes(labels[:input_size])
bounding_boxes
# Out:
# {'./dataset/images/5_10_jpg.rf.5639f7a69885c595fc4b54e55dbf5148.jpg': [()],
#  './dataset/images/5_11_jpg.rf.99ee6f27d5d5f353e00506003993302a.jpg': [()],
#  './dataset/images/5_12_jpg.rf.f46713998d4579eabe3baf01d0bc605c.jpg': [()],
#  './dataset/images/5_13_jpg.rf.d4959906ae25dc3b28e2e43553764b1c.jpg': [()],
#  './dataset/images/5_14_jpg.rf.af89c1ce48edc27397830962d43d5c6a.jpg': [()],
#  './dataset/images/5_15_jpg.rf.02c45be3c76c4201f24dd386e060ed8c.jpg': [()],
#  './dataset/images/5_16_jpg.rf.ac71b8803fe5c99c3fc1e6867351c0bb.jpg': [()],
#  './dataset/images/5_17_jpg.rf.0611b10e50517e4323c47fc36301167c.jpg': [()],
#  './dataset/images/5_22_jpg.rf.368e2a41bf84be83076f603939cbd052.jpg': [()],
#  './dataset/images/5_23_jpg.rf.b98dce2a37d470d921751909d8030cee.jpg': [()],
#  './dataset/images/5_24_jpg.rf.36c0b527bff3e31a8effc6d45c8be54a.jpg': [()],
#  './dataset/images/5_25_jpg.rf.0a5f2cffb167f51cdfbd781fa2c84799.jpg': [()],
#  './dataset/images/5_26_jpg.rf.56a14e695c9d4f114bc7695b4eeee5c4.jpg': [()],
#  './dataset/images/5_27_jpg.rf.27629ee7ad1efad4706917a4d365f885.jpg': [()],
#  './dataset/images/5_28_jpg.rf.3eabd78da3af251b71e0089ac63f9c88.jpg': [()],
#  './dataset/images/5_29_jpg.rf.39ba79c54fb99e4cc4a23da875301235.jpg': [()],
#  './dataset/images/5_30_jpg.rf.5c6a3cbc4657cfe85bc750da4bf13dda.jpg': [()],
#  './dataset/images/5_5_jpg.rf.ee324fcd83bdb85967b7524f4e6dfab2.jpg': [()],
#  './dataset/images/5_6_jpg.rf.472c92efe7d67437c82b35657cb82eb6.jpg': [()],
#  './dataset/images/5_7_jpg.rf.3295b062cfb02ea4935c3175d3067ca0.jpg': [()],
#  './dataset/images/5_8_jpg.rf.a78c03de0e6f923fd9112cd282c906cd.jpg': [()],
#  './dataset/images/5_9_jpg.rf.93750bdd7aee64f1ea7cff182e27d530.jpg': [()],
#  './dataset/images/acc1-1-_jpg.rf.e85683033791fa2a31f118259ab992eb.jpg': [()],
#  './dataset/images/acc1-13-_jpg.rf.a9a91bca62e9c6f250f550c9808026f7.jpg': [(0.0,
#    0.4390625,
#    0.49296875,
#    0.3203125,
#    0.31328125)],
#  './dataset/images/acc1-14-_jpg.rf.f59b6d09b4c954950df2c8c058fb8770.jpg': [(0.0,
#    0.428125,
#    0.49921875,
#    0.425,
#    0.4125)],
#  './dataset/images/acc1-15-_jpg.rf.f1c18dddcda5bb85a144a0a816ae6193.jpg': [()],
#  './dataset/images/acc1-2-_jpg.rf.0c0e2392df6b9d17d1771991dfdc76ad.jpg': [(0.0,
#    0.3421875,
#    0.7640625,
#    0.359375,
#    0.334375)],
#  './dataset/images/acc1-3-_jpg.rf.eae24490bfdbb357cfd45639b9729a82.jpg': [(0.0,
#    0.3015625,
#    0.69609375,
#    0.48125,
#    0.36328125)],
#  './dataset/images/acc1-4-_jpg.rf.df4b93de5e73a19502a03b22eae18a62.jpg': [(0.0,
#    0.31953125,
#    0.7140625,
#    0.5625,
#    0.39609375)],
#  './dataset/images/acc1-5-_jpg.rf.8608bc850afe8a12acd0f23eac968986.jpg': [()],
#  './dataset/images/acc1-6-_jpg.rf.0acbfc206f6e8d9021f00903414e7909.jpg': [(0.0,
#    0.3125,
#    0.35703125,
#    0.2953125,
#    0.2953125)],
#  './dataset/images/acc1-7-_jpg.rf.7c24f920f793551e90c72fd3d92ec5d5.jpg': [()],
#  './dataset/images/ezgif-frame-001_jpg.rf.7a10900a61aa9b8030862d026e47cba2.jpg': [()],
#  './dataset/images/ezgif-frame-001_jpg.rf.90df4a751f8c1aeca11fecd141193981.jpg': [()],
#  './dataset/images/ezgif-frame-002_jpg.rf.1c4aa89694facd03f33ad5e308c82748.jpg': [()],
#  './dataset/images/ezgif-frame-002_jpg.rf.64c25b035c9b346616f54497e921b4a8.jpg': [()],
#  './dataset/images/ezgif-frame-003_jpg.rf.26c83fd31ce45450bb29dcf03cfea02c.jpg': [()],
#  './dataset/images/ezgif-frame-003_jpg.rf.575c882db18bbf5c1aa2d3b67f5ab39a.jpg': [()],
#  './dataset/images/ezgif-frame-004_jpg.rf.54b9d88f5a6d77ebe4d4f75a08b8618d.jpg': [()],
#  './dataset/images/ezgif-frame-004_jpg.rf.775679de6f9c9f473d20cc552b7a03ad.jpg': [()],
#  './dataset/images/ezgif-frame-005_jpg.rf.192d5fb055ddc9c13034370b07ef6313.jpg': [()],
#  './dataset/images/ezgif-frame-005_jpg.rf.82934634a600cb97fa3f8bad3f1ec17d.jpg': [()],
#  './dataset/images/ezgif-frame-006_jpg.rf.83a6829634a0ed7db945f1001ae52203.jpg': [()],
#  './dataset/images/ezgif-frame-006_jpg.rf.fb7fca85fb0e8c707825b4183d430654.jpg': [()],
#  './dataset/images/ezgif-frame-007_jpg.rf.ceac019216ee1df6dffdd54ec8e49012.jpg': [()],
#  './dataset/images/ezgif-frame-007_jpg.rf.d0d6a4f810dcea2ea947510552f29542.jpg': [()],
#  './dataset/images/ezgif-frame-008_jpg.rf.94881b17368c960d54f6bf1245f32204.jpg': [()],
#  './dataset/images/ezgif-frame-008_jpg.rf.bf39fc1478057be99286b0a4c337f737.jpg': [()],
#  './dataset/images/ezgif-frame-009_jpg.rf.9ab642e238e53f092453c890c159f578.jpg': [()],
#  './dataset/images/ezgif-frame-009_jpg.rf.d98ceab54ddf36900a4ca4ea052f54c0.jpg': [()],
#  './dataset/images/ezgif-frame-010_jpg.rf.6b3b6eaa5fa771a8368af734989bd627.jpg': [()],
#  './dataset/images/ezgif-frame-010_jpg.rf.d225571f087a5d929891216ded083406.jpg': [()],
#  './dataset/images/ezgif-frame-011_jpg.rf.27d5e2a9f0a2a2d3fb72e0d131b34175.jpg': [()],
#  './dataset/images/ezgif-frame-011_jpg.rf.c08a1ae17bf7e14cb585fcbbecf02f2c.jpg': [()],
#  './dataset/images/ezgif-frame-012_jpg.rf.22297917ed9b0faabda134c31cd995fd.jpg': [()],
#  './dataset/images/ezgif-frame-012_jpg.rf.9fc81424e92e18e65c71f7e914605cd5.jpg': [()],
#  './dataset/images/ezgif-frame-013_jpg.rf.0ff0bc6421c993975efea7fdb9a3d7c9.jpg': [()],
#  './dataset/images/ezgif-frame-013_jpg.rf.9ac4c863e6575ffae2b51199aef701cd.jpg': [()],
#  './dataset/images/ezgif-frame-014_jpg.rf.287ae76ad28dd61d097a03c23e6b5840.jpg': [()],
#  './dataset/images/ezgif-frame-014_jpg.rf.a3f40e4c00ffeab40b98842a106f2b25.jpg': [()],
#  './dataset/images/ezgif-frame-015_jpg.rf.7dc3d3a5841ddfd4679b738171ec8eb3.jpg': [()],
#  './dataset/images/ezgif-frame-015_jpg.rf.ae19c96e2aba1d3a491afbd93bae700a.jpg': [()],
#  './dataset/images/ezgif-frame-016_jpg.rf.4938a375fb7b1cca5e6034bf9318b57c.jpg': [()],
#  './dataset/images/ezgif-frame-016_jpg.rf.ca0bcea30501ae4af64fee661b1dc9e1.jpg': [()],
#  './dataset/images/ezgif-frame-017_jpg.rf.52c1c06e085a4f0924344c0989f935fd.jpg': [()],
#  './dataset/images/ezgif-frame-017_jpg.rf.98af792749d80eda29d06f0712f06158.jpg': [()],
#  './dataset/images/ezgif-frame-018_jpg.rf.22b96861d590a69856616ee23663a2ea.jpg': [()],
#  './dataset/images/ezgif-frame-018_jpg.rf.96792c8e8aa1ee53027f36af9352e0e3.jpg': [()],
#  './dataset/images/ezgif-frame-019_jpg.rf.128de1e65b8f320a464f19707c7024d8.jpg': [()],
#  './dataset/images/ezgif-frame-019_jpg.rf.54b7f119c25ad8c90698398a9b640616.jpg': [()],
#  './dataset/images/ezgif-frame-020_jpg.rf.8ee4d626955dcbf767f4866943549760.jpg': [()],
#  './dataset/images/ezgif-frame-020_jpg.rf.eabd8827fc2260e9c05bf55c80e1e13a.jpg': [()],
#  './dataset/images/ezgif-frame-021_jpg.rf.15fe840bac36ecc49035237dcd60671e.jpg': [()],
#  './dataset/images/ezgif-frame-021_jpg.rf.a0276faf0d2dbf9f39d2a697714b869b.jpg': [()],
#  './dataset/images/ezgif-frame-022_jpg.rf.cf059c4c875aa350a520b8af03406814.jpg': [()],
#  './dataset/images/ezgif-frame-023_jpg.rf.0461caf58636d97621df1dbc99627636.jpg': [()],
#  './dataset/images/ezgif-frame-024_jpg.rf.c1da323772d5b4dbaae840ede6ede10f.jpg': [()],
#  './dataset/images/ezgif-frame-024_jpg.rf.d5ce065fc385ec4d85531516df55ad4d.jpg': [()],
#  './dataset/images/ezgif-frame-025_jpg.rf.173fbb88e9127bb3b44b7e58da9f39d0.jpg': [()],
#  './dataset/images/ezgif-frame-025_jpg.rf.c1d871f7ce9885f59c0f3c28a6815584.jpg': [()],
#  './dataset/images/ezgif-frame-026_jpg.rf.9a9b45dcc59a5d2d05a4e007a00880be.jpg': [()],
#  './dataset/images/ezgif-frame-026_jpg.rf.ae1fcb7287067b1e75d90590008e21c7.jpg': [()],
#  './dataset/images/ezgif-frame-027_jpg.rf.369d02b727a9be39f2e3fb352ef4d3e6.jpg': [()],
#  './dataset/images/ezgif-frame-027_jpg.rf.a9ddf7f1726d56e2565363fcf8983055.jpg': [()],
#  './dataset/images/ezgif-frame-028_jpg.rf.62473df9e742951e304f82faf0783f40.jpg': [()],
#  './dataset/images/ezgif-frame-028_jpg.rf.d9f43c45b96ab8572defe8bae6b7ab45.jpg': [()],
#  './dataset/images/ezgif-frame-029_jpg.rf.b4ae9f33a425243ad31f2930f4deab55.jpg': [()],
#  './dataset/images/ezgif-frame-029_jpg.rf.d9c6e73532d52e77acee22b0db79cdde.jpg': [()],
#  './dataset/images/ezgif-frame-030_jpg.rf.b833ba99cde217064ec5f7f7712a8246.jpg': [()],
#  './dataset/images/ezgif-frame-030_jpg.rf.d8b1ec17c34de3ab1fed10140bad398a.jpg': [()],
#  './dataset/images/ezgif-frame-031_jpg.rf.a54f7d833470211f0c12a79be6cdfcff.jpg': [()],
#  './dataset/images/ezgif-frame-031_jpg.rf.cd9efaff67869e5ab69bf577439d7526.jpg': [()],
#  './dataset/images/ezgif-frame-032_jpg.rf.2a507922c01a0dee306a2a7ebbf629cf.jpg': [()],
#  './dataset/images/ezgif-frame-032_jpg.rf.63957bbb0d9713896161bf6c15e1b92a.jpg': [()],
#  './dataset/images/ezgif-frame-033_jpg.rf.559b8a4e7bed66b267598f65488dcaa7.jpg': [()],
#  './dataset/images/ezgif-frame-033_jpg.rf.67d6ee4fddc18e6c1c48c40b2acc8102.jpg': [()],
#  './dataset/images/ezgif-frame-034_jpg.rf.1c63f13627998466d0dcda96e9f96484.jpg': [()],
#  './dataset/images/ezgif-frame-034_jpg.rf.4e9bae725a55ed48db99225ed3283d41.jpg': [()],
#  './dataset/images/ezgif-frame-035_jpg.rf.dfa7661e772937b7abb4a4734cc99c6a.jpg': [()],
#  './dataset/images/ezgif-frame-035_jpg.rf.e287c6b9e77c1c89d64748e6bab9a4c9.jpg': [()],
#  './dataset/images/ezgif-frame-036_jpg.rf.1dae861bc5ed894e7c36457fd1ad896b.jpg': [()],
#  './dataset/images/ezgif-frame-036_jpg.rf.b5f68c1f4365aa9a08247e14a901db7a.jpg': [()],
#  './dataset/images/ezgif-frame-037_jpg.rf.47da3084fa069884e0ee9a5cd751d283.jpg': [()],
#  './dataset/images/ezgif-frame-037_jpg.rf.4c37bc2796725e9ce1099c1b8d778bf0.jpg': [()],
#  './dataset/images/ezgif-frame-038_jpg.rf.781297986228202e2691aaec5307f530.jpg': [(0.0,
#    0.240625,
#    0.58984375,
#    0.23984375,
#    0.228125)],
#  './dataset/images/ezgif-frame-038_jpg.rf.8675debc4a074a7ce44485fe25b2f70d.jpg': [()],
#  './dataset/images/ezgif-frame-039_jpg.rf.a41b854dbde41a543c94818c7cd97a4c.jpg': [()],
#  './dataset/images/ezgif-frame-039_jpg.rf.cc7a948cc51aea8bf0b92ef68b8ba967.jpg': [(0.0,
#    0.25,
#    0.5953125,
#    0.25859375,
#    0.20625)],
#  './dataset/images/ezgif-frame-040_jpg.rf.06747e1391895da477637d087b443ece.jpg': [()],
#  './dataset/images/ezgif-frame-040_jpg.rf.813f14af6e2dd5427bc6bbfdaf88e35f.jpg': [(0.0,
#    0.2625,
#    0.590625,
#    0.2796875,
#    0.190625)],
#  './dataset/images/ezgif-frame-041_jpg.rf.e0fdeb61520af552054967954d9e16a6.jpg': [()],
#  './dataset/images/ezgif-frame-041_jpg.rf.fe80afdb3c2410b10fd9672987f162d3.jpg': [(0.0,
#    0.27421875,
#    0.590625,
#    0.29375,
#    0.2015625)],
#  './dataset/images/ezgif-frame-042_jpg.rf.ce4c4c7bfe1f23e6515a3f8ca76f6c56.jpg': [()],
#  './dataset/images/ezgif-frame-042_jpg.rf.d455618b9b146133f81493e3358dc09c.jpg': [(0.0,
#    0.27890625,
#    0.59140625,
#    0.30078125,
#    0.21484375)],
#  './dataset/images/ezgif-frame-043_jpg.rf.8f9475f894ab87343d42ea8c13916657.jpg': [()],
#  './dataset/images/ezgif-frame-043_jpg.rf.e93db350f1d6d1ec78875d326d09c7aa.jpg': [(0.0,
#    0.2921875,
#    0.59765625,
#    0.29921875,
#    0.21640625)],
#  './dataset/images/ezgif-frame-044_jpg.rf.360fcb67806a597f5743d4e9049c4cf8.jpg': [()],
#  './dataset/images/ezgif-frame-044_jpg.rf.6de16d60931c4fd0294ec0113635c3f6.jpg': [(0.0,
#    0.296875,
#    0.57578125,
#    0.2953125,
#    0.19375)],
#  './dataset/images/ezgif-frame-045_jpg.rf.6d7a8674ec4d573073b5c94dae6611cf.jpg': [(0.0,
#    0.30546875,
#    0.60078125,
#    0.2875,
#    0.2)],
#  './dataset/images/ezgif-frame-045_jpg.rf.d5ad0d1e34eab3fdda19510799be9242.jpg': [()],
#  './dataset/images/ezgif-frame-046_jpg.rf.58bafed15631d50fc538d4aac47211d8.jpg': [()],
#  './dataset/images/ezgif-frame-046_jpg.rf.732d66db43aa92f8a39d1075893e5f95.jpg': [(0.0,
#    0.315625,
#    0.58515625,
#    0.2921875,
#    0.275)],
#  './dataset/images/ezgif-frame-047_jpg.rf.4721d709ca8b856dfcda5220fe1d628c.jpg': [(0.0,
#    0.309375,
#    0.61015625,
#    0.28359375,
#    0.2359375)],
#  './dataset/images/ezgif-frame-047_jpg.rf.aa137abf5ade5c0f70d83a46c0f8879d.jpg': [(0.0,
#    0.2609375,
#    0.40546875,
#    0.465625,
#    0.47109375)],
#  './dataset/images/ezgif-frame-048_jpg.rf.e39be404ce46980338538132c1889c28.jpg': [(0.0,
#    0.2578125,
#    0.415625,
#    0.3765625,
#    0.425)],
#  './dataset/images/ezgif-frame-048_jpg.rf.e8912ac4230d3e6649c1ff24e9f61a05.jpg': [(0.0,
#    0.32109375,
#    0.596875,
#    0.259375,
#    0.24140625)],
#  './dataset/images/ezgif-frame-049_jpg.rf.3d31c2036dbba0e869ad7122c22e4015.jpg': [()],
#  './dataset/images/ezgif-frame-049_jpg.rf.677c8f7388a8cffc9c7ea593c8504b9c.jpg': [(0.0,
#    0.23125,
#    0.38828125,
#    0.2578125,
#    0.346875)],
#  './dataset/images/ezgif-frame-050_jpg.rf.20d51d3eace915797597d1fa9b74b75f.jpg': [()],
#  './dataset/images/ezgif-frame-050_jpg.rf.e275d5b76e683857afc44b4a4417dfe1.jpg': [(0.0,
#    0.24765625,
#    0.40390625,
#    0.2625,
#    0.2890625)],
#  './dataset/images/ezgif-frame-051_jpg.rf.045cfb8f0622649090cbbf3b1991e3a4.jpg': [(0.0,
#    0.38125,
#    0.546875,
#    0.42109375,
#    0.38125)],
#  './dataset/images/ezgif-frame-051_jpg.rf.601f642430b7f87273400fa2081166f3.jpg': [(0.0,
#    0.26875,
#    0.428125,
#    0.2828125,
#    0.315625)],
#  './dataset/images/ezgif-frame-052_jpg.rf.90449e7817c3c3279974375779e138c5.jpg': [(0.0,
#    0.3890625,
#    0.5484375,
#    0.378125,
#    0.278125)],
#  './dataset/images/ezgif-frame-052_jpg.rf.c48882c354ba2af4b111e0a617f7f8e4.jpg': [(0.0,
#    0.27265625,
#    0.42421875,
#    0.26328125,
#    0.3078125)],
#  './dataset/images/ezgif-frame-053_jpg.rf.649baf64796461cd31323e4ab5855054.jpg': [(0.0,
#    0.24921875,
#    0.41953125,
#    0.29375,
#    0.25390625)],
#  './dataset/images/ezgif-frame-053_jpg.rf.bd4179fcec26d0890654eefd0de703f4.jpg': [(0.0,
#    0.4046875,
#    0.5625,
#    0.434375,
#    0.27890625)],
#  './dataset/images/ezgif-frame-054_jpg.rf.64af6242e48ee713304a13632bece3d9.jpg': [(0.0,
#    0.2515625,
#    0.41015625,
#    0.2859375,
#    0.284375)],
#  './dataset/images/ezgif-frame-054_jpg.rf.6cb91731ca78ca6ca706e6fb9e6f761b.jpg': [(0.0,
#    0.4171875,
#    0.55,
#    0.4390625,
#    0.3265625)],
#  './dataset/images/ezgif-frame-055_jpg.rf.0fd01390b75a3245f45418a4fbf6b9bc.jpg': [(0.0,
#    0.4359375,
#    0.55703125,
#    0.45546875,
#    0.3234375)],
#  './dataset/images/ezgif-frame-055_jpg.rf.8ff4d3637b4e6a45d8560db93c583db8.jpg': [(0.0,
#    0.26171875,
#    0.4078125,
#    0.290625,
#    0.24140625)],
#  './dataset/images/ezgif-frame-056_jpg.rf.550e4b5b5f0c337e786d934e24a4937e.jpg': [(0.0,
#    0.4359375,
#    0.55234375,
#    0.4703125,
#    0.34140625)],
#  './dataset/images/ezgif-frame-056_jpg.rf.e2ca3c510d8120fb374ceb63a3ce10b3.jpg': [(0.0,
#    0.23984375,
#    0.4078125,
#    0.24765625,
#    0.26328125)],
#  './dataset/images/ezgif-frame-057_jpg.rf.922e53672a917e4e290c64e66f9d8b63.jpg': [(0.0,
#    0.22734375,
#    0.3984375,
#    0.234375,
#    0.21171875)],
#  './dataset/images/ezgif-frame-057_jpg.rf.adce9538db50a45935ab7f69de3b96ae.jpg': [(0.0,
#    0.4546875,
#    0.571875,
#    0.4828125,
#    0.38046875)],
#  './dataset/images/ezgif-frame-058_jpg.rf.0f0d35758451119e77bd0f8a31aa42ce.jpg': [(0.0,
#    0.459375,
#    0.56171875,
#    0.4671875,
#    0.315625)],
#  './dataset/images/ezgif-frame-058_jpg.rf.9269345c28375697c0ffd4470ff7a854.jpg': [(0.0,
#    0.23203125,
#    0.4046875,
#    0.225,
#    0.2578125)],
#  './dataset/images/ezgif-frame-059_jpg.rf.6cccaf5e3401eb041ea72b33234e9292.jpg': [(0.0,
#    0.46953125,
#    0.56015625,
#    0.49453125,
#    0.346875)],
#  './dataset/images/ezgif-frame-059_jpg.rf.bfe3c43345f204aa89c8c7ab35c20b43.jpg': [(0.0,
#    0.20234375,
#    0.428125,
#    0.175,
#    0.2375)],
#  './dataset/images/ezgif-frame-060_jpg.rf.deedb387569e067ea737fdf7d6728920.jpg': [(0.0,
#    0.47109375,
#    0.54609375,
#    0.4890625,
#    0.3234375)],
#  './dataset/images/ezgif-frame-060_jpg.rf.e7465edef085b65cf358be3fa1e3145f.jpg': [(0.0,
#    0.2078125,
#    0.425,
#    0.1828125,
#    0.24765625)],
#  './dataset/images/ezgif-frame-061_jpg.rf.50ae1a83309cf333936fc3f67053872f.jpg': [(0.0,
#    0.4796875,
#    0.55234375,
#    0.471875,
#    0.34140625)],
#  './dataset/images/ezgif-frame-061_jpg.rf.d5c0d382a4259d29d95bd48078a52b39.jpg': [(0.0,
#    0.19140625,
#    0.4328125,
#    0.1625,
#    0.2640625)],
#  './dataset/images/ezgif-frame-062_jpg.rf.68059165ebc45ad428f4be78e58abfa2.jpg': [(0.0,
#    0.2015625,
#    0.428125,
#    0.1765625,
#    0.259375)],
#  './dataset/images/ezgif-frame-062_jpg.rf.7c0eb42b1ae4090b448593f368eafad7.jpg': [(0.0,
#    0.4984375,
#    0.56640625,
#    0.4703125,
#    0.29140625)],
#  './dataset/images/ezgif-frame-063_jpg.rf.0963a52f9a323643513ca32bd7b6fec3.jpg': [(0.0,
#    0.20234375,
#    0.4296875,
#    0.19140625,
#    0.23046875)],
#  './dataset/images/ezgif-frame-063_jpg.rf.37467e72a1185f4a620b47bcea4a139d.jpg': [(0.0,
#    0.50078125,
#    0.5578125,
#    0.4859375,
#    0.35234375)],
#  './dataset/images/ezgif-frame-064_jpg.rf.18bdf8b2600f151b6cbdb20baf41bd4a.jpg': [(0.0,
#    0.196875,
#    0.42890625,
#    0.16484375,
#    0.2171875)],
#  './dataset/images/ezgif-frame-064_jpg.rf.77819340dea35ef26a4adb9fead6984c.jpg': [(0.0,
#    0.49921875,
#    0.565625,
#    0.50390625,
#    0.31796875)],
#  './dataset/images/ezgif-frame-065_jpg.rf.a5a46b9cb346b4e60cf2670d27e3bdc4.jpg': [(0.0,
#    0.5046875,
#    0.55625,
#    0.440625,
#    0.3375)],
#  './dataset/images/ezgif-frame-065_jpg.rf.e147ccf7523a4857843c5112bdc78c3b.jpg': [(0.0,
#    0.21796875,
#    0.43828125,
#    0.196875,
#    0.22421875)],
#  './dataset/images/ezgif-frame-066_jpg.rf.236553b0fd59e11dd3423674490e0a06.jpg': [(0.0,
#    0.5109375,
#    0.56484375,
#    0.421875,
#    0.30078125)],
#  './dataset/images/ezgif-frame-066_jpg.rf.fdb8946d733e61a9a3d3844ec7e6c53b.jpg': [(0.0,
#    0.21640625,
#    0.42265625,
#    0.15703125,
#    0.2265625)],
#  './dataset/images/ezgif-frame-067_jpg.rf.5eab60227ecfc302d3f23d33037045b0.jpg': [(0.0,
#    0.21328125,
#    0.44921875,
#    0.20625,
#    0.19140625)],
#  './dataset/images/ezgif-frame-067_jpg.rf.e82d4841c0f514ca69809c225e3637ba.jpg': [(0.0,
#    0.51015625,
#    0.5796875,
#    0.453125,
#    0.4015625)],
#  './dataset/images/ezgif-frame-068_jpg.rf.a5447f235cbf33e50c141ff63e9fbc64.jpg': [(0.0,
#    0.5171875,
#    0.5609375,
#    0.453125,
#    0.36484375)],
#  './dataset/images/ezgif-frame-068_jpg.rf.dacb3216e36c94ae24250c0ea067f517.jpg': [(0.0,
#    0.2,
#    0.44453125,
#    0.17734375,
#    0.29296875)],
#  './dataset/images/ezgif-frame-069_jpg.rf.340864b1fedb96002cc5077a06e48a3b.jpg': [(0.0,
#    0.20703125,
#    0.4515625,
#    0.18125,
#    0.228125)],
#  './dataset/images/ezgif-frame-069_jpg.rf.5ef17ec7f09e8f250bbbefac0f45aafc.jpg': [(0.0,
#    0.5234375,
#    0.58984375,
#    0.428125,
#    0.37265625)],
#  './dataset/images/ezgif-frame-070_jpg.rf.4a86f52c6e8115022429b72eb85f2e23.jpg': [(0.0,
#    0.52421875,
#    0.56015625,
#    0.44140625,
#    0.31328125)],
#  './dataset/images/ezgif-frame-070_jpg.rf.9ebbf64dd36fa6c059a1266d9b4e9292.jpg': [(0.0,
#    0.20625,
#    0.43984375,
#    0.1765625,
#    0.2953125)],
#  './dataset/images/ezgif-frame-071_jpg.rf.b3c0892b8abc243c278baa24c74e45d9.jpg': [(0.0,
#    0.20546875,
#    0.44765625,
#    0.165625,
#    0.23203125)],
#  './dataset/images/ezgif-frame-071_jpg.rf.ce09a630b5ce3d4746b446ae21f11006.jpg': [(0.0,
#    0.5328125,
#    0.57734375,
#    0.43671875,
#    0.31328125)],
#  './dataset/images/ezgif-frame-072_jpg.rf.4913f4968992d45c8d8f0d2b172136a5.jpg': [(0.0,
#    0.20625,
#    0.4328125,
#    0.1421875,
#    0.253125)],
#  './dataset/images/ezgif-frame-072_jpg.rf.dacbd6095d725b98e7f1d58b33743416.jpg': [(0.0,
#    0.5390625,
#    0.5625,
#    0.44921875,
#    0.27265625)],
#  './dataset/images/ezgif-frame-073_jpg.rf.02b20a2973dbba5a28b61843a63c033b.jpg': [(0.0,
#    0.546875,
#    0.60078125,
#    0.45,
#    0.3109375)],
#  './dataset/images/ezgif-frame-073_jpg.rf.2424d846825c01bf55f38313d7523dbf.jpg': [(0.0,
#    0.209375,
#    0.44609375,
#    0.1609375,
#    0.234375)],
#  './dataset/images/ezgif-frame-074_jpg.rf.9d01e1e5c8cfe33c3e1f2d4eee7fe3dd.jpg': [(0.0,
#    0.18828125,
#    0.46171875,
#    0.178125,
#    0.2375)],
#  './dataset/images/ezgif-frame-074_jpg.rf.b17595c38eb850592713251e552fa166.jpg': [(0.0,
#    0.3453125,
#    0.5984375,
#    0.2609375,
#    0.21171875)],
#  './dataset/images/ezgif-frame-075_jpg.rf.6a62ee8c87a50173097ac01ef3481c88.jpg': [(0.0,
#    0.25703125,
#    0.434375,
#    0.40078125,
#    0.55078125)],
#  './dataset/images/ezgif-frame-075_jpg.rf.e54cf04a5fd0240d43950a9fd2d10fe5.jpg': [(0.0,
#    0.34296875,
#    0.59921875,
#    0.26015625,
#    0.26875)],
#  './dataset/images/ezgif-frame-076_jpg.rf.2da4f734e39ac41b60636d4356b831a9.jpg': [(0.0,
#    0.25546875,
#    0.37890625,
#    0.44140625,
#    0.55078125)],
#  './dataset/images/ezgif-frame-076_jpg.rf.f57639aa15451e133a378c309a432344.jpg': [(0.0,
#    0.359375,
#    0.61953125,
#    0.25,
#    0.24765625)],
#  './dataset/images/ezgif-frame-077_jpg.rf.84d389f39b8156bcfddf54eb8403b1ea.jpg': [(0.0,
#    0.35390625,
#    0.5671875,
#    0.26953125,
#    0.28828125)],
#  './dataset/images/ezgif-frame-077_jpg.rf.bd8a1eb5195472c9ce6c1025b7a34b4c.jpg': [(0.0,
#    0.2625,
#    0.40625,
#    0.40234375,
#    0.48828125)],
#  './dataset/images/ezgif-frame-078_jpg.rf.91525b1a86d3b9007fdd2895022f967d.jpg': [(0.0,
#    0.27265625,
#    0.40859375,
#    0.38203125,
#    0.4984375)],
#  './dataset/images/ezgif-frame-078_jpg.rf.efc197e692fda88b494d56844ededd4c.jpg': [(0.0,
#    0.39921875,
#    0.61484375,
#    0.2828125,
#    0.2609375)],
#  './dataset/images/ezgif-frame-079_jpg.rf.2032f5dcd09ab33571a0fadbe845c47f.jpg': [(0.0,
#    0.25546875,
#    0.396875,
#    0.35,
#    0.52578125)],
#  './dataset/images/ezgif-frame-079_jpg.rf.8e38d959813b3f2536c55708df78529f.jpg': [(0.0,
#    0.40859375,
#    0.61796875,
#    0.24140625,
#    0.28359375)],
#  './dataset/images/ezgif-frame-080_jpg.rf.4b97217509dc2ddee8df8d7106653ce9.jpg': [(0.0,
#    0.26328125,
#    0.40390625,
#    0.375,
#    0.51640625)],
#  './dataset/images/ezgif-frame-080_jpg.rf.e29c3bdc24cc6cea66ef37e767c1c9df.jpg': [(0.0,
#    0.415625,
#    0.6125,
#    0.18984375,
#    0.2125)],
#  './dataset/images/ezgif-frame-081_jpg.rf.67d4a4407867667877bb0d8c5e59a3e0.jpg': [(0.0,
#    0.28671875,
#    0.375,
#    0.3875,
#    0.45859375)],
#  './dataset/images/ezgif-frame-081_jpg.rf.a43ae4360bb474594413c1a3b45fe967.jpg': [()],
#  './dataset/images/ezgif-frame-082_jpg.rf.3da64cb385568992acb7e8165e43aaea.jpg': [(0.0,
#    0.25703125,
#    0.42734375,
#    0.28203125,
#    0.4421875)],
#  './dataset/images/ezgif-frame-082_jpg.rf.be1c082bda8812547d6aab6f69353f26.jpg': [()],
#  './dataset/images/ezgif-frame-083_jpg.rf.11150370824809696aa00f3efc1c6a19.jpg': [()],
#  './dataset/images/ezgif-frame-083_jpg.rf.d514bb01785c8ab5a060fdbff3260541.jpg': [(0.0,
#    0.23203125,
#    0.38828125,
#    0.265625,
#    0.40234375)],
#  './dataset/images/ezgif-frame-084_jpg.rf.5baef21b0727b12e875ab4eabec219de.jpg': [()],
#  './dataset/images/ezgif-frame-084_jpg.rf.9135182ded36f2ee16fb64e99db8b5ab.jpg': [(0.0,
#    0.26328125,
#    0.37890625,
#    0.33828125,
#    0.428125)],
#  './dataset/images/ezgif-frame-085_jpg.rf.0e302df6dde32eaf2819177d11a1e8ab.jpg': [()],
#  './dataset/images/ezgif-frame-085_jpg.rf.75972a016ca9018eb57824d4edbb3c69.jpg': [(0.0,
#    0.2578125,
#    0.39296875,
#    0.28671875,
#    0.4625)]}

# %%
import matplotlib.pyplot as plt
import matplotlib.patches as patches
from PIL import Image
import io

# Function to draw a single bounding box on image
def draw_box(image_data, box, color='red'):
    # Unpack the box values
    if box: 
        _, x_center, y_center, width, height = box
        # Convert to x, y from top left and width and height in pixels
        x = (x_center - (width / 2)) * image_data.size[0]
        y = (y_center - (height / 2)) * image_data.size[1]
        width_pixels = width * image_data.size[0]
        height_pixels = height * image_data.size[1]

        # Create the rectangle and add it to the plot
        rect = patches.Rectangle((x, y), width_pixels, height_pixels, linewidth=1, edgecolor=color, facecolor='none')
        return rect
    else:
        return None

# Function to visualize bounding boxes
def visualize_boxes(images, boxes):
    fig, axs = plt.subplots(len(images), 1, figsize=(10, len(images)))
    if len(images) == 1:
        axs = [axs]  # Make it iterable

    for ax, image_path in zip(axs, images):
        # Load the image
        with open(image_path, 'rb') as img_file:
            image_data = Image.open(io.BytesIO(img_file.read()))
        ax.imshow(image_data)
        
        # Draw the boxes
        if image_path in boxes:
            for box in boxes[image_path]:
                rect = draw_box(image_data, box)
                if rect:
                    ax.add_patch(rect)
                
        # Remove axis for better visualization
        ax.axis('off')

    plt.tight_layout()
    plt.show()

# Visualize the bounding boxes on the images
visualize_boxes(images[:input_size], bounding_boxes)
